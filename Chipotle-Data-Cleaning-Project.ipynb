# %% [markdown]
# # Data Cleaning

# %% [markdown]
# ## Step 1. Import the necessary libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Step 2. Import the dataset

# %%
df = pd.read_table("C:/Users/hp/Downloads/chipotle.tsv")
df
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %% [markdown]
# ## Step 3. Assign it to a variable called chipo.

# %%
chipo=pd.read_table("C:/Users/hp/Downloads/chipotle.tsv")
chipo
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %% [markdown]
# ## Step 4. See the first 10 entries

# %%
chipo.head(10)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# ...

# %% [markdown]
# ### Step 5. What is the number of observations in the dataset?

# %%
# Solution 1

chipo.shape[0]
# Out:
# 4622

# %%
# Solution 2

chipo.shape
# Out:
# (4622, 5)

# %% [markdown]
# ### Step 6. What is the number of columns in the dataset?

# %%
chipo.shape[1]
# Out:
# 5

# %% [markdown]
# ### Step 7. Print the name of all the columns.

# %%
print(chipo.columns)
# Out:
# Index(['order_id', 'quantity', 'item_name', 'choice_description',
#        'item_price'],
#       dtype='object')

# %% [markdown]
# ### Step 8. How is the dataset indexed?

# %%
chipo.index
# Out:
# RangeIndex(start=0, stop=4622, step=1)

# %% [markdown]
# ### Step 9. Which was the most-ordered item?

# %%
chipo["item_name"].value_counts().idxmax()
# Out:
# 'Chicken Bowl'

# %% [markdown]
# ### Step 10. For the most-ordered item, how many items were ordered?

# %%
most_ordered_item = chipo["item_name"].value_counts()
most_ordered_item.max()
# Out:
# 726

# %% [markdown]
# ### Step 11. What was the most ordered item in the choice_description column?

# %%
chipo["choice_description"].value_counts().head(1)
# Out:
# choice_description
# [Diet Coke]    134
# Name: count, dtype: int64

# %% [markdown]
# ### Step 12. How many items were orderd in total?

# %%
chipo["quantity"].sum()
# Out:
# np.int64(4972)

# %% [markdown]
# ### Step 13. Turn the item price into a float

# %% [markdown]
# #### Step 13.a. Check the item price type

# %%
chipo["item_price"].dtype
# Out:
# dtype('O')

# %% [markdown]
# #### Step 13.b. Create a lambda function and change the type of item price

# %%
chipo["item_price"] = chipo["item_price"].str.replace("$","")
chipo["item_price"]
# Out:
# 0        2.39
# 1        3.39
# 2        3.39
# 3        2.39
# 4       16.98
#          ...
# 4617    11.75
# 4618    11.75
# 4619    11.25
# 4620     8.75
# 4621     8.75
# Name: item_price, Length: 4622, dtype: object

# %%
chipo["item_price"] = chipo["item_price"].apply(lambda x:float(x))
chipo["item_price"]
# Out:
# 0        2.39
# 1        3.39
# 2        3.39
# 3        2.39
# 4       16.98
#         ...
# 4617    11.75
# 4618    11.75
# 4619    11.25
# 4620     8.75
# 4621     8.75
# Name: item_price, Length: 4622, dtype: float64

# %% [markdown]
# #### Step 13.c. Check the item price type

# %%
chipo["item_price"].dtype
# Out:
# dtype('float64')

# %% [markdown]
# ### Step 14. How much was the revenue for the period in the dataset?

# %%
revenue = chipo["item_price"].sum()
revenue
# Out:
# np.float64(34500.16)

# %% [markdown]
# ### Step 15. How many orders were made in the period?

# %%
number_of_order =chipo.shape[0]  #counts total number of rows/items
number_of_order
# Out:
# 4622

# %%
number_of_order= chipo["order_id"].nunique() #counts total unique orders  
number_of_order
# Out:
# 1834

# %% [markdown]
# ### Step 16. What is the average revenue amount per order?

# %%
# Solution 1
total_revenue =chipo["item_price"].sum()  
total_revenue
# Out:
# np.float64(34500.16)

# %%
total_order= chipo["order_id"].nunique() #total unique orders
total_order
# Out:
# 1834

# %%
# Solution 2
average_revenue_per_order= total_revenue / total_order
average_revenue_per_order
# Out:
# np.float64(18.811428571428575)

# %% [markdown]
# ### Step 17. How many different items are sold?

# %%
num_of_different_items= chipo["item_name"].nunique()
num_of_different_items
# Out:
# 50
